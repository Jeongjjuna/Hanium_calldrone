# %%
import os
print(os.getcwd())
# Out:
# /home/jovyan

# %%
# %cd /home/jovyan/pistol/data
# Out:
# /home/jovyan/pistol/data

# %%
# !unzip -qq "/home/jovyan/pistol/data/labels.zip"

# %%
# !unzip -qq "/home/jovyan/pistol/data/images.zip"
# Out:
# replace armas (1)_jpg.rf.c4150f819f9dc2ae75336e5b64e67d67.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
from glob import glob

img_list = glob('/home/jovyan/pistol/data/*.jpg')
txt_list = glob('/home/jovyan/pistol/data/*.txt')

print(len(img_list))
print(len(txt_list))
# Out:
# 2971
# 2971

# %%
# %cd /home/jovyan
# !git clone http://github.com/ultralytics/yolov5.git
# Out:
# /home/jovyan
# 'yolov5'에 복제합니다...
# ...
# remote: Enumerating objects: 12192, done.
# remote: Total 12192 (delta 0), reused 0 (delta 0), pack-reused 12192
# 오브젝트를 받는 중: 100% (12192/12192), 11.95 MiB | 2.91 MiB/s, 완료.
# 델타를 알아내는 중: 100% (8441/8441), 완료.

# %%
# %cd /home/jovyan/yolov5
# !pip install -r requirements.txt
# Out:
# /home/jovyan/yolov5
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 2.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 983.3 kB/s eta 0:00:0000:0100:06
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 3.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 3.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 KB 2.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 KB 3.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 3.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 KB 2.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.7/160.7 KB 3.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=2000)

print(len(train_img_list), len(val_img_list))
# Out:
# 2376 595

# %%
import yaml

with open('/home/jovyan/pistol/train.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')

with open('/home/jovyan/pistol/val.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')

with open('/home/jovyan/pistol/data.yaml', 'r') as f:
    data = yaml.load(f)

print(data)
# Out:
# {'train': '../train/images', 'val': '../valid/images', 'nc': 1, 'names': ['pistol']}

# %%
data['train'] = '/home/jovyan/pistol/train.txt'
data['val'] = 'data['train'] = '/home/jovyan/pistol/val.txt''

# %%
with open('/home/jovyan/pistol/data.yaml', 'w') as f:
    yaml.dump(data, f)
    
print(data)
# Out:
# {'train': '/home/jovyan/pistol/train.txt', 'val': '/home/jovyan/pistol/val.txt', 'nc': 1, 'names': ['pistol']}

# %%
# %cd /home/jovyan/yolov5

# !python train.py --img 416 --batch 16 --epochs 50 --data /home/jovyan/pistol/data.yaml --cfg /home/jovyan/yolov5/models/yolov5s.yaml --weights /home/jovyan/yolov5/yolov5s.pt
# Out:
# /home/jovyan/yolov5
# train: weights=/home/jovyan/yolov5/yolov5s.pt, cfg=/home/jovyan/yolov5/models/yolov5s.yaml, data=/home/jovyan/pistol/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# ...
# github: up to date with http://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-246-g2dd3db0 Python-3.8.10 torch-1.9.0+cu111 CUDA:0 (NVIDIA A100-SXM4-40GB, 40536MiB)
#
# ...

# %%
# !pip3 install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchaudio==0.9.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#
# × The package index page being used does not have a proper HTML doctype declaration.
# ╰─> Problematic URL: https://download.pytorch.org/whl/torch_stable.html
#
# note: This is an issue with the page at the URL mentioned above.
# hint: You might need to reach out to the owner of that package index, to get this fixed. See https://github.com/pypa/pip/issues/10825 for context.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 350.1 kB/s eta 0:00:00:0100:240m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 1.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 1.4 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0
#     Uninstalling torch-1.11.0:
#       Successfully uninstalled torch-1.11.0
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 1.9.0+cu111

# %%
import sys
print(sys.version)
# Out:
# 3.8.10 (default, Nov 26 2021, 20:14:08)
# [GCC 9.3.0]

# %%
# !python detect.py --weights /home/jovyan/yolov5/runs/train/exp8/weights/best.pt --source /home/jovyan/pistol/test.mp4
# Out:
# detect: weights=['/home/jovyan/yolov5/runs/train/exp8/weights/best.pt'], source=/home/jovyan/pistol/test.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-246-g2dd3db0 Python-3.8.10 torch-1.9.0+cu111 CUDA:0 (NVIDIA A100-SXM4-40GB, 40536MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/19596) /home/jovyan/pistol/test.mp4: 384x640 1 pistol, Done. (0.015s)
# video 1/1 (2/19596) /home/jovyan/pistol/test.mp4: 384x640 1 pistol, Done. (0.007s)
# video 1/1 (3/19596) /home/jovyan/pistol/test.mp4: 384x640 1 pistol, Done. (0.007s)
# ...
